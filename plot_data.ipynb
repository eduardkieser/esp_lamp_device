# %%
from data_viz import plot_device_data, load_device_data_as_df


data_dir = 'lamp_data'

# load the data
df = load_device_data_as_df()
# Out:
# Available devices:
# 1. 0000CCF7B833E864
# 2. 00008017AE9E9EF0_mini
# 3. 00008017AE9E9EF0

# %%
df.columns = ['timestamp', 'device', 'value', 'value_type']

df.value.plot()
df.value_type.plot()
# Out:
# <Axes: >
